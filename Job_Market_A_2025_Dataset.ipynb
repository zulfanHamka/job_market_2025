# %% [markdown]
# <a href="https://colab.research.google.com/github/zulfanHamka/job_market_2025/blob/main/Job_Market_A_2025_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data set ini menyediakan informasi terstruktur tentang lowongan pekerjaan pada tahun 2025, termasuk judul pekerjaan, perusahaan, lokasi, industri, gaji, dan deskripsi pekerjaan. Data set ini dirancang untuk peneliti, mahasiswa, dan
#
# ***praktisi yang ingin menganalisis tren pasar tenaga kerja, memprediksi gaji, mengklasifikasikan pekerjaan, dan menerapkan teknik pemrosesan bahasa alami (NLP) pada deskripsi pekerjaan.***

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/gcolab/JobMarket-A2025Dataset/JobMarket2025.csv'

# %%
df = pd.read_csv(file_path)

# %%
df.head(5)
# Out:
#            id                                              title  \
# 0  5410474609                              Mechanical Pipefitter
# 1  5381519011  International Trade Policy Editor [Startup Pol...
# 2  5389371380                                   Domestic Cleaner
# 3  5403097985                       Early Years BABY Room Leader
# 4  5400306117                           Senior Back-End Engineer
#
#               company_name                 category_label  \
# 0               Dodd Group      Trade & Construction Jobs
# 1          Applio Ventures                  Graduate Jobs
# 2   Maid2Clean Suffolk Ltd  Domestic help & Cleaning Jobs
# 3  Jesters Childcare Essex                  Teaching Jobs
# 4         Eligible Limited                        IT Jobs
#
#                   category_tag         country      location_display  \
# 0      trade-construction-jobs  United Kingdom  King's Lynn, Norfolk
# 1                graduate-jobs  United Kingdom            London, UK
# ...

# %% [markdown]
# list data yang akan di hapus
# - id,category_tag,location_display, location_area, latitude, longitide,creatd_dt,redirect_url,adref

# %%
df["country"].unique()
# Out:
# array(['United Kingdom', 'USA', 'Germany', 'France', 'Netherlands',
#        'Italy', 'Spain', 'Switzerland'], dtype=object)

# %%
df["contract_type"].unique()
# Out:
# array(['permanent', 'contract', nan], dtype=object)

# %%
df.isnull().sum()
# Out:
# id                        0
# title                     0
# company_name            214
# category_label            0
# category_tag              0
# country                   0
# location_display          0
# location_area             0
# latitude                743
# longitude               743
# contract_type          3154
# contract_time          3015
# salary_min             2456
# salary_max             2465
# salary_mid             2456
# salary_is_predicted       0
# created_dt                0
# created_date              0
# redirect_url              0
# adref                     0
# dtype: int64
